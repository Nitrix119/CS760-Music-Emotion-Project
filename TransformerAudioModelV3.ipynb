# %%
import os
import pandas as pd
import librosa
import numpy as np
import torch
from torch.serialization import safe_globals
from datasets import Dataset
import random
from sklearn.model_selection import train_test_split
from transformers import AutoFeatureExtractor, AutoModelForAudioClassification, TrainingArguments, Trainer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from transformers import GenerationConfig
from tabulate import tabulate

# %%
#Load Data
df = pd.read_csv('multimodal_dataset_normalized.csv')
display(df.head())
# Out:
#   Audio_Song Lyric_Song  Arousal  Valence Quadrant     Emotion lyric_id  \
# 0       A005       L055  0.78750  0.68750       Q1    Surprise     L055
# 1       A011       L061  0.68125  0.85625       Q1   Happiness     L061
# 2       A014       L064  0.86250  0.72500       Q1    Surprise     L064
# 3       A019       L069  0.78125  0.81875       Q1  Excitement     L069
# 4       A022       L072  0.76875  0.83750       Q1  Excitement     L072
#
#    word_count  unique_word_count  lexical_diversity  ...  rms_mean   rms_std  \
# 0    0.583846          -0.032136          -1.136493  ... -1.315662 -1.165455
# 1   -0.549140          -0.974930          -1.286263  ...  0.107522 -0.408386
# 2    0.415581          -0.162177          -1.133997  ...  0.361195 -0.265328
# 3   -0.229436          -0.308472          -0.401603  ... -0.219121 -0.979168
# 4   -0.599619          -0.828634          -0.755787  ...  0.916902  0.959027
#
#    beat_strength  low_energy_ratio  energy_entropy  brightness    warmth  \
# 0       0.896397         -0.700513       -0.145042    1.086334 -0.092941
# 1       0.006682          0.068631        0.750471    0.147696  0.040220
# 2       0.710477         -0.673247        0.854382    1.970159 -0.798261
# 3      -0.061622         -0.340510        1.062094    0.474343  0.110013
# 4      -0.008507         -0.482841        0.298920   -0.169472  0.269772
#
#        activity harmonic_energy_ratio  harmonicity
# 0  [0.06471955]             -1.951364    -0.583475
# 1  [0.18521025]              0.472448    -0.078961
# 2  [0.17745368]             -0.949336    -0.454885
# 3  [0.13742129]              0.244760    -0.150335
# 4  [0.22606403]             -0.078616    -0.234134
#
# [5 rows x 97 columns]

# %%
#Emotion Class
unique_items = df["Quadrant"].unique()
print(unique_items)

all_classes = unique_items
class_to_idx = {cls: i for i, cls in enumerate(all_classes)}
print("Class to index mapping:", class_to_idx)
# Out:
# ['Q1' 'Q2' 'Q3' 'Q4']
# Class to index mapping: {'Q1': 0, 'Q2': 1, 'Q3': 2, 'Q4': 3}

# %%
#Extract path and emotion
data_dir = "MERGE_Bimodal_Complete/audio_wav"
labels_dict = {f"{data_dir}/{row['Quadrant']}/{row['Audio_Song']}.wav": row['Quadrant'] for _, row in df.iterrows()}
print(labels_dict)
# Out:
# {'MERGE_Bimodal_Complete/audio_wav/Q1/A005.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A011.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A014.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A019.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A022.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A024.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A039.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A042.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A043.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A047.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A050.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A064-116.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A077-122.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A086-123.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A092-96.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A094-110.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A095-113.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A100-124.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A101-111.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A102-114.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A104-119.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A105-117.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A107-115.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A114-120.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A115-84.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A128-109.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A132-121.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A146-118.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A148-102.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A152-108.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A153-130.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A160-149.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A162.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A166.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A167.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A187.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/A196.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000040773.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000045345.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000080053.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000091401.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000093583.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000103874.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000105492.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000119987.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000128573.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000146966.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000174580.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000185601.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000197431.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000225806.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000245808.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000252574.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000271454.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000310204.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000315363.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000325093.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000369188.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000426880.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000475876.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000497520.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000518591.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000540286.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000546446.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000556349.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000615489.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000621840.wav': 'Q1', 'MERGE_Bimodal_Complete/audio_wav/Q1/MT0000664362.wav': 'Q1 ...

# %%
X_list = list(labels_dict.keys())
y_list = [labels_dict[fp] for fp in X_list]

X_trainval, X_test, y_trainval, y_test = train_test_split(X_list, y_list, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.25, random_state=42)

print("Train size:", len(X_train), len(y_train))
print("Val size:", len(X_val), len(y_val))
print("Test size:", len(X_test), len(y_test))

def make_dataset(paths, labels):
    return Dataset.from_dict({"audio": paths, "label": labels})

train_ds = make_dataset(X_train, y_train)
eval_ds = make_dataset(X_val, y_val)
test_ds = make_dataset(X_test, y_test)

print("Train shape:", train_ds.shape)
print("Val shape:", eval_ds.shape)
print("Test shape:", test_ds.shape)
# Out:
# Train size: 1329 1329
# Val size: 443 443
# Test size: 444 444
# Train shape: (1329, 2)
# Val shape: (443, 2)
# Test shape: (444, 2)

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained("MIT/ast-finetuned-audioset-10-10-0.4593")
label_list = sorted(set(y_list))
label2id = {l: i for i, l in enumerate(label_list)}
id2label = {i: l for l, i in label2id.items()}

# %%
def preprocess(example):
    audio_array, _ = librosa.load(example["audio"], sr=16000)
    inputs = feature_extractor(audio_array, sampling_rate=16000)
    inputs["label"] = label2id[example["label"]]
    return inputs

train_ds = train_ds.map(preprocess)
eval_ds = eval_ds.map(preprocess)
test_ds = test_ds.map(preprocess)
# Out:
# Map:   0%|          | 0/1329 [00:00<?, ? examples/s]
# Map:   0%|          | 0/443 [00:00<?, ? examples/s]
# Map:   0%|          | 0/444 [00:00<?, ? examples/s]

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)  # Single-label prediction
    return {
        "accuracy": accuracy_score(labels, predictions),
        "precision": precision_score(labels, predictions, average="macro", zero_division=1),
        "recall": recall_score(labels, predictions, average="macro", zero_division=1),
        "f1": f1_score(labels, predictions, average="macro", zero_division=1),
    }

# %%
class AudioCollator:
    def __call__(self, batch):
        input_values = [torch.tensor(b["input_values"]).squeeze() for b in batch]
        labels = [b["label"] for b in batch]
        return {
            "input_values": torch.stack(input_values),
            "labels": torch.tensor(labels)
        }

# %%
model = AutoModelForAudioClassification.from_pretrained(
    "MIT/ast-finetuned-audioset-10-10-0.4593",
    num_labels=len(label_list),
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes=True  # if your label count differs
)
# Out:
# Some weights of ASTForAudioClassification were not initialized from the model checkpoint at MIT/ast-finetuned-audioset-10-10-0.4593 and are newly initialized because the shapes did not match:
# - classifier.dense.bias: found shape torch.Size([527]) in the checkpoint and torch.Size([4]) in the model instantiated
# - classifier.dense.weight: found shape torch.Size([527, 768]) in the checkpoint and torch.Size([4, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./ast-emotion2",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=10,
    logging_dir="./logs",
    logging_steps=10,
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=eval_ds,
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
    data_collator=AudioCollator(),
)

trainer.train()
# Out:
# C:\Users\GGPC\AppData\Local\Temp\ipykernel_9168\2445830484.py:14: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 24
#       1 training_args = TrainingArguments(
#       2     output_dir="./ast-emotion2",
#       3     eval_strategy="epoch",
#    (...)     11     report_to="none"
#      12 )
#      14 trainer = Trainer(
#      15     model=model,
#      16     args=training_args,
#    (...)     21     data_collator=AudioCollator(),
#      22 )
# ---> 24 trainer.train()
#
# File E:\CS760-Music-Emotion-Project\.venv\Lib\site-packages\transformers\trainer.py:2328, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326         hf_hub_utils.enable_progress_bars()
#    2327 else:
# -> 2328     return inner_training_loop(
#    2329         args=args,
#    2330         resume_from_checkpoint=resume_from_checkpoint,
#    2331         trial=trial,
#    2332         ignore_keys_for_eval=ignore_keys_for_eval,
#    2333     )
#
# File E:\CS760-Music-Emotion-Project\.venv\Lib\site-packages\transformers\trainer.py:2623, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2621 update_step += 1
#    2622 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# -> 2623 batch_samples, num_items_in_batch = self.get_batch_samples(epoch_iterator, num_batches, args.device)
#    2624 # Store the number of batches for current gradient accumulation
#    2625 # This is used to correctly scale the loss when the last accumulation step has fewer batches
#    2626 self.current_gradient_accumulation_steps = len(batch_samples)
#
# File E:\CS760-Music-Emotion-Project\.venv\Lib\site-packages\transformers\trainer.py:5581, in Trainer.get_batch_samples(self, epoch_iterator, num_batches, device)
#    5579 for _ in range(num_batches):
#    5580     try:
# -> 5581         batch_samples.append(next(epoch_iterator))
#    5582     except StopIteration:
#    5583         break
#
# File E:\CS760-Music-Emotion-Project\.venv\Lib\site-packages\accelerate\data_loader.py:567, in DataLoaderShard.__iter__(self)
#     565 # We iterate one batch ahead to check when we are at the end
#     566 try:
# --> 567     current_batch = next(dataloader_iter)
#     568 except StopIteration:
#     569     self.end()
#
# File E:\CS760-Music-Emotion-Project\.venv\Lib\site-packages\torch\utils\data\dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File E:\CS760-Music-Emotion-Project\.venv\Lib\site-packages\torch\utils\data\dataloader.py:790, in _SingleProcessDataLoaderIter._next_data(self)
#     788 def _next_data(self):
#     789     index = self._next_index()  # may raise StopIteration
# --> 790     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791     if self._pin_memory:
#     792         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File E:\CS760-Music-Emotion-Project\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# Cell In[8], line 3, in AudioCollator.__call__(self, batch)
#       2 def __call__(self, batch):
# ----> 3     input_values = [torch.tensor(b["input_values"]).squeeze() for b in batch]
#       4     labels = [b["label"] for b in batch]
#       5     return {
#       6         "input_values": torch.stack(input_values),
#       7         "labels": torch.tensor(labels)
#       8     }
#
# KeyError: 'input_values'

# %%
# Check results on the test set
metrics = trainer.evaluate(eval_dataset=test_ds)
print(tabulate(metrics.items(), headers=["Metric", "Value"], tablefmt="pretty"))
# Out:
#     <div>
#
#       <progress value='56' max='56' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [56/56 01:11]
#     </div>
# +-------------------------+--------------------+
# |         Metric          |       Value        |
# +-------------------------+--------------------+
# |        eval_loss        | 1.6291677951812744 |
# |      eval_accuracy      | 0.7072072072072072 |
# |     eval_precision      | 0.6938133253554661 |
# |       eval_recall       | 0.6962662860488947 |
# |         eval_f1         | 0.6937526554939218 |
# |      eval_runtime       |      73.1952       |
# | eval_samples_per_second |       6.066        |
# |  eval_steps_per_second  |       0.765        |
# |          epoch          |        10.0        |
# +-------------------------+--------------------+

# %%
# Save the whole model to be loaded easily later
model_save_path = "models/ast_lyrics_saved"
model.save_pretrained(model_save_path)
feature_extractor.save_pretrained(model_save_path)
# Out:
# ['models/ast_lyrics_saved\\preprocessor_config.json']
